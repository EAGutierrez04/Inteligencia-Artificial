# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
datos = sns.load_dataset("titanic")
datos
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
datos.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
# Eliminar columnas inservibles
delete_columns = ['embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town', 'alive', 'alone']
datos.drop(delete_columns, axis=1, inplace=True)
datos
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare
# 0           0       3    male  22.0      1      0   7.2500
# 1           1       1  female  38.0      1      0  71.2833
# 2           1       3  female  26.0      0      0   7.9250
# 3           1       1  female  35.0      1      0  53.1000
# 4           0       3    male  35.0      0      0   8.0500
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0  13.0000
# 887         1       1  female  19.0      0      0  30.0000
# 888         0       3  female   NaN      1      2  23.4500
# 889         1       1    male  26.0      0      0  30.0000
# 890         0       3    male  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
codificador = LabelEncoder()
datos["sex"] = codificador.fit_transform(datos["sex"])
datos
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare
# 0           0       3    1  22.0      1      0   7.2500
# 1           1       1    0  38.0      1      0  71.2833
# 2           1       3    0  26.0      0      0   7.9250
# 3           1       1    0  35.0      1      0  53.1000
# 4           0       3    1  35.0      0      0   8.0500
# ..        ...     ...  ...   ...    ...    ...      ...
# 886         0       2    1  27.0      0      0  13.0000
# 887         1       1    0  19.0      0      0  30.0000
# 888         0       3    0   NaN      1      2  23.4500
# 889         1       1    1  26.0      0      0  30.0000
# 890         0       3    1  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
copiaDatos = datos.copy()

# %%
# Dividir el conjunto en x (explicativas) y Y (respuestas)
y = datos["survived"]
datos.drop("survived", axis=1, inplace=True)
datos
# Out:
#      pclass  sex   age  sibsp  parch     fare
# 0         3    1  22.0      1      0   7.2500
# 1         1    0  38.0      1      0  71.2833
# 2         3    0  26.0      0      0   7.9250
# 3         1    0  35.0      1      0  53.1000
# 4         3    1  35.0      0      0   8.0500
# ..      ...  ...   ...    ...    ...      ...
# 886       2    1  27.0      0      0  13.0000
# 887       1    0  19.0      0      0  30.0000
# 888       3    0   NaN      1      2  23.4500
# 889       1    1  26.0      0      0  30.0000
# 890       3    1  32.0      0      0   7.7500
#
# [891 rows x 6 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pclass  891 non-null    int64
#  1   sex     891 non-null    int32
#  2   age     714 non-null    float64
#  3   sibsp   891 non-null    int64
#  4   parch   891 non-null    int64
#  5   fare    891 non-null    float64
# dtypes: float64(2), int32(1), int64(3)
# memory usage: 38.4 KB

# %%
# Reecuento de cuantos valores nulos existen 
print(datos.isnull().sum())
# Out:
# pclass      0
# sex         0
# age       177
# sibsp       0
# parch       0
# fare        0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(datosA, y, test_size=0.30)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
# Sin tratar los valores nulos, no se podrá realizar la regresión logística
lr.fit(X_train, Y_train)
pred = lr.predict(X_test)
print(metrics.accuracy_score(pred, Y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       2 lr = LogisticRegression()
#       3 # Sin tratar los valores nulos, no se podrá realizar la regresión logística
# ----> 4 lr.fit(X_train, Y_train)
#       5 pred = lr.predict(X_test)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:1222, in LogisticRegression.fit(self, X, y, sample_weight)
#    1219 else:
# ...

# %% [markdown]
# ## Eliminar columnas con valores faltantes

# %% [markdown]
# ## Medidas estadísticas

# %% [markdown]
# Imputar con:
# - Media: Promedio de los datos (se ve afectada por valores extremo)
# - Mediana: Valores que se encuentran justamente en la posición central de la serie de datos ordenada
# - Moda: El más frecuente.
