# %%
# import sys
# !{sys.executable} -m pip install datasets

# %%
from datasets import load_dataset
dataset = load_dataset('imdb')
dataset = dataset.map(lambda x: {"label": 1 if x["label"] == "pos" else 0})

# %%
from transformers import BertTokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
def tokenizar(muestra):
    return tokenizer(muestra["text"], padding = "max_length", truncation = True)

# %%
tokenized_datasets = dataset.map(tokenizar, batched = True)

# %%
from torch.utils.data import DataLoader

# %%
train_dataset = tokenized_datasets['train'].shuffle(seed=42).select(range(10000))
val_dataset = tokenized_datasets['test'].shuffle(seed=42).select(range(1000))
train_dataloader = DataLoader(train_dataset, batch_size=8)
val_dataloader = DataLoader(val_dataset, batch_size=8)

# %%
from transformers import BertForSequenceClassification

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased", num_labels = 2)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# import AdamW
from torch.optim import AdamW

# %%
optimizer = AdamW(model.parameters(), lr=5e-5)

# %%
from torch import optim

# %%
optimizer = optim.AdamW(model.parameters(), lr=5e-5)

# %%
# pip install tf-keras
# pip install transformers[torch]
from transformers import Trainer, TrainingArguments
# Out:
# WARNING:tensorflow:From C:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# liberar memoria
import torch
torch.cuda.empty_cache()

# %%
training_args = TrainingArguments(
    output_dir = './results',
    eval_strategy = 'epoch',
    learning_rate = 2e-5,
    per_device_train_batch_size = 4,
    per_device_eval_batch_size = 4,
    num_train_epochs = 3,
    weight_decay = 0.01,
)

# %%
trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset=train_dataset,
    eval_dataset = val_dataset,
)

# %% [raw]
# trainer.train()

# %%
results = trainer.evaluate()
print(results)
# Out:
# C:\Users\Usuario\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='179' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [179/250 09:19 < 03:43, 0.32 it/s]
#     </div>

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# %%
text = ["Me encanta este producto", "No me gustó para nada"]

# %%
inputs = tokenizer(texts, return_tensors="pt", padding= True, truncation = True).to(device)
outputs = model(**inputs)
predictions = torch.argmax(outputs.logits, dim=1)
print(predictions)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot = (x == predictions.cpu().numpy())
plt.xlabel("Sentimiento")
plt.ylabel("Frecuencias")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sns.countplot = (x == predictions.cpu().numpy())
#       2 plt.xlabel("Sentimiento")
#       3 plt.ylabel("Frecuencias")
#
# NameError: name 'x' is not defined

# %%
predictions_numpy = predictions.cpu().numpy()
predictions_numpy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 predictions_numpy = predictions.cpu().numpy()
#       2 predictions_numpy
#
# NameError: name 'predictions' is not defined

# %%
sns.countplot(x=predictions_numpy)
plt.title("Conteo de predicciones por clase")
plt.xlabel("Clase predicha")
plt.ylabel("Lol")
plt.show();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.countplot(x=predictions_numpy)
#       2 plt.title("Conteo de predicciones por clase")
#       3 plt.xlabel("Clase predicha")
#
# NameError: name 'predictions_numpy' is not defined

# %%
texts_en=[
    "This is a brilliant idea!",
    "I'm so proud of your accomplishment.",
    "You have a wonderful sense of humor.",    
    "Today is going to be a great day.",
    "I truly believe in you.",
    "Your help has been invaluable.", 
    "We are going to have so much fun!",
    "That's a perfect solution.",
    "You light up the room.",
    "I feel incredibly grateful for this opportunity.",
    "This is an absolute disaster.",
    "I'm so disappointed in you.",
    "Your attitude is unacceptable.",
    "This is the worst day ever.",
    "I can't believe you did that.",
    "This is a complete waste of time.",
    "You never listen to me.",
    "I'm exhausted and miserable.",
    "This food is disgusting.",
    "Everything is going wrong."
]

# %%
inputs_en = tokenizer(texts_en, return_tensors = "pt", padding = True, truncation = True).to(device)
outputs_en = model(**inputs_en)
predictions_en = torch.argmax(outputs_en.logits, dim=1)
print(predictions_en)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 inputs_en = tokenizer(texts_en, return_tensors = "pt", padding = True, truncation = True).to(device)
#       2 outputs_en = model(**inputs_en)
#       3 predictions_en = torch.argmax(outputs_en.logits, dim=1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:2938, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2936     if not self._in_target_context_manager:
#    2937         self._switch_to_input_mode()
# -> 2938     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2939 if text_target is not None:
#    2940     self._switch_to_target_mode()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:3026, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3021         raise ValueError(
#    3022             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    3023             f" {len(text_pair)}."
#    3024         )
#    3025     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 3026     return self.batch_encode_plus(
#    3027         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3028         add_special_tokens=add_special_tokens,
#    3029         padding=padding,
#    3030         truncation=truncation,
#    3031         max_length=max_length,
#    3032         stride=stride,
#    3033         is_split_into_words=is_split_into_words,
#    3034         pad_to_multiple_of=pad_to_multiple_of,
#    3035         padding_side=padding_side,
#    3036         return_tensors=return_tensors,
#    3037         return_token_type_ids=return_token_type_ids,
#    3038         return_attention_mask=return_attention_mask,
#    3039         return_overflowing_tokens=return_overflowing_tokens,
#    3040         return_special_tokens_mask=return_special_tokens_mask,
#    3041         return_offsets_mapping=return_offsets_mapping,
#    3042         return_length=return_length,
#    3043         verbose=verbose,
#    3044         split_special_tokens=split_special_tokens,
#    3045         **kwargs,
#    3046     )
#    3047 else:
#    3048     return self.encode_plus(
#    3049         text=text,
#    3050         text_pair=text_pair,
#    (...)
#    3068         **kwargs,
#    3069     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:3227, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3217 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3218 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3219     padding=padding,
#    3220     truncation=truncation,
#    (...)
#    3224     **kwargs,
#    3225 )
# -> 3227 return self._batch_encode_plus(
#    3228     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3229     add_special_tokens=add_special_tokens,
#    3230     padding_strategy=padding_strategy,
#    3231     truncation_strategy=truncation_strategy,
#    3232     max_length=max_length,
#    3233     stride=stride,
#    3234     is_split_into_words=is_split_into_words,
#    3235     pad_to_multiple_of=pad_to_multiple_of,
#    3236     padding_side=padding_side,
#    3237     return_tensors=return_tensors,
#    3238     return_token_type_ids=return_token_type_ids,
#    3239     return_attention_mask=return_attention_mask,
#    3240     return_overflowing_tokens=return_overflowing_tokens,
#    3241     return_special_tokens_mask=return_special_tokens_mask,
#    3242     return_offsets_mapping=return_offsets_mapping,
#    3243     return_length=return_length,
#    3244     verbose=verbose,
#    3245     split_special_tokens=split_special_tokens,
#    3246     **kwargs,
#    3247 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils.py:893, in PreTrainedTokenizer._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#     890     second_ids = get_input_ids(pair_ids) if pair_ids is not None else None
#     891     input_ids.append((first_ids, second_ids))
# --> 893 batch_outputs = self._batch_prepare_for_model(
#     894     input_ids,
#     895     add_special_tokens=add_special_tokens,
#     896     padding_strategy=padding_strategy,
#     897     truncation_strategy=truncation_strategy,
#     898     max_length=max_length,
#     899     stride=stride,
#     900     pad_to_multiple_of=pad_to_multiple_of,
#     901     padding_side=padding_side,
#     902     return_attention_mask=return_attention_mask,
#     903     return_token_type_ids=return_token_type_ids,
#     904     return_overflowing_tokens=return_overflowing_tokens,
#     905     return_special_tokens_mask=return_special_tokens_mask,
#     906     return_length=return_length,
#     907     return_tensors=return_tensors,
#     908     verbose=verbose,
#     909     split_special_tokens=split_special_tokens,
#     910 )
#     912 return BatchEncoding(batch_outputs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils.py:980, in PreTrainedTokenizer._batch_prepare_for_model(self, batch_ids_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_length, verbose, split_special_tokens)
#     969         batch_outputs[key].append(value)
#     971 batch_outputs = self.pad(
#     972     batch_outputs,
#     973     padding=padding_strategy.value,
#    (...)
#     977     return_attention_mask=return_attention_mask,
#     978 )
# --> 980 batch_outputs = BatchEncoding(batch_outputs, tensor_type=return_tensors)
#     982 return batch_outputs
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:248, in BatchEncoding.__init__(self, data, encoding, tensor_type, prepend_batch_axis, n_sequences)
#     244     n_sequences = encoding[0].n_sequences
#     246 self._n_sequences = n_sequences
# --> 248 self.convert_to_tensors(tensor_type=tensor_type, prepend_batch_axis=prepend_batch_axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\tokenization_utils_base.py:734, in BatchEncoding.convert_to_tensors(self, tensor_type, prepend_batch_axis)
#     732 elif tensor_type == TensorType.PYTORCH:
#     733     if not is_torch_available():
# --> 734         raise ImportError("Unable to convert output to PyTorch tensors format, PyTorch is not installed.")
#     735     import torch
#     737     def as_tensor(value, dtype=None):
#
# ImportError: Unable to convert output to PyTorch tensors format, PyTorch is not installed.

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
MODEL_NAME_ES = "openai/whisper-large-v3"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME_ES)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME_ES)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 4
#       2 MODEL_NAME_ES = "openai/whisper-large-v3"
#       3 tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME_ES)
# ----> 4 model = AutoModelForSequenceClassification.from_pretrained(MODEL_NAME_ES)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2157, in DummyObject.__getattribute__(cls, key)
#    2155 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2156     return super().__getattribute__(key)
# -> 2157 requires_backends(cls, cls._backends)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\utils\import_utils.py:2126, in requires_backends(obj, backends)
#    2124 # Raise an error for users who might not realize that classes without "TF" are torch-only
#    2125 if "torch" in backends and "tf" not in backends and not is_torch_available() and is_tf_available():
# -> 2126     raise ImportError(PYTORCH_IMPORT_ERROR_WITH_TF.format(name))
#    2128 # Raise the inverse error for PyTorch users trying to load TF classes
#    2129 if "tf" in backends and "torch" not in backends and is_torch_available() and not is_tf_available():
#
# ImportError:
# AutoModelForSequenceClassification requires the PyTorch library but it was not found in your environment.
# However, we were able to find a TensorFlow installation. TensorFlow classes begin
# with "TF", but are otherwise identically named to our PyTorch classes. This
# means that the TF equivalent of the class you tried to import would be "TFAutoModelForSequenceClassification".
# If you want to use TensorFlow, please use TF classes instead!
#
# If you really do want to use PyTorch please go to
# https://pytorch.org/get-started/locally/ and follow the instructions that
# match your environment.
