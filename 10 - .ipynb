# %%
from datasets import load_dataset
dataset = load_dataset("imdb")
dataset = dataset.map(lambda x: {"label": 1 if x["label"] == "pos" else 0})
# Out:
# README.md: 0.00B [00:00, ?B/s]
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\datasets--imdb. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
from transformers import BertTokenizer
tekenizer = BertTokenizer.from_pretrained("bert-base-uncased")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\User\.cache\huggingface\hub\models--bert-base-uncased. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ...

# %%
def tokenizar (muestra):
    return tekenizer(muestra["text"], padding = "max_length", truncation =True)

# %%
tokenized_datasets = dataset.map(tokenizar, batched = True)
# Out:
# ...
# Map:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
from Torch.utils.data import DataLoader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from Torch.utils.data import DataLoader
#
# ModuleNotFoundError: No module named 'Torch'

# %%
train_dataset = tokenized_datasets["train"].shuffle(seed = 42).select(range(10000))
val_dataset = tokenized_datasets["test"].shuffle(seed=42).select(range(1000))
train_dataloader = DataLoader(train_dataset, batch_size = 8)
val_dataloader = DataLoader(val_dataset, batch_size=8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train_dataset = tokenized_datasets["train"].shuffle(seed = 42).select(range(10000))
#       2 val_dataset = tokenized_datasets["test"].shuffle(seed=42).select(range(1000))
#       3 train_dataloader = DataLoader(train_dataset, batch_size = 8)
#
# NameError: name 'tokenized_datasets' is not defined

# %%
from transformers import BertForSequenceClassification
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from transformers import BertForSequenceClassification
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\__init__.py:27
#      24 from typing import TYPE_CHECKING
#      26 # Check the dependencies satisfy the minimal versions required.
# ---> 27 from . import dependency_versions_check
#      28 from .utils import (
#      29     OptionalDependencyNotAvailable,
#      30     _LazyModule,
#    (...)
#      36     is_pretty_midi_available,
#      37 )
#      39 # Note: the following symbols are deliberately exported with `as`
#      40 # so that mypy, pylint or other static linters can recognize them,
#      41 # given that they are not exported using `__all__` in this file.
#
# ...

# %%
model = BertForSequenceClassification.from_pretrained("bert-case-uncased", num_labels=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model = BertForSequenceClassification.from_pretrained("bert-case-uncased", num_labels=2)
#
# NameError: name 'BertForSequenceClassification' is not defined
